# %%
dbutils.widgets.text("catalog_name","")

# %%
catalog_nm = dbutils.widgets.get("catalog_name")

# %%
df = spark.sql(f"select * from {catalog_nm}.information_schema.columns")
display(df)

# %%
# %sql
select * from demo_catalog.information_schema.columns;
